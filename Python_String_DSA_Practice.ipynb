# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/string-dsa-python/blob/main/Python_String_DSA_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Reverse Words in a Sentence

#Input
#I love Python programming
#Output
#programming Python love I

sentence = input("Enter a sentence:")

words = sentence.split()

reversed_words = []

for i in range(len(words)-1,-1,-1):
  reversed_words.append(words[i])

result = " ".join(reversed_words)
print(result)
# Out:
# Enter a sentence:#I love Python programming
# programming Python love #I

# %%
#Check if One String is a Rotation of Another

string1 = input('Enter a string:')
string2 = input('Enter a string:')

if len(string1) != len(string2):
  print("Strings are not Rotation")
else:
  combined = string1 + string1

  if string2 in combined:
    print('string2 is rotation of string1')
  else:
    print('string2 is not rotation of string1')
# Out:
# Enter a string:ABCD
# Enter a string:BCDA
# string2 is rotation of string1

# %%
#Find All Duplicate Characters

string = input("Enter a string:")

char_count = {}

for char in string:
  if char in char_count:
    char_count[char] += 1
  else:
    char_count[char] = 1

print("Duplicate Characters:",char_count)
# Out:
# Enter a string:Programming
# Duplicate Characters: {'P': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
string = input("Enter a string:")

frequency = {}

for ch in string:
  frequency[ch] = frequency.get(ch,0) + 1

print("Duplicate Characters")

found = False

for ch in frequency:
  if frequency[ch] > 1:
    print(ch)
    found = True

if not found:
  print("No Duplicate Characters")
# Out:
# Enter a string:Programming
# Duplicate Characters
# r
# g
# m

# %%
#Find the Second Most Frequent Character

string = input("Enter a string:")

frequency = {}

for ch in string:
  frequency[ch] = frequency.get(ch,0) + 1

frequencies = list(set(frequency.values()))

if len(frequencies) < 2:
  print("No second most frequent characters")

else:
  frequencies.sort(reverse=True)
  second_most_frequency = frequencies[1]

  found = False
  for ch in frequency:
    if frequency[ch] == second_most_frequency:
      print(ch)
      found = True
      break

  if not found:
    print("No second most frequent characters")
# Out:
# Enter a string:aabbbbccccc
# b

# %%
#Replace Multiple Spaces with a Single Space

#Input
#Python    is     very   easy
#Output
#Python is very easy

sentence = input("Enter a sentence:")

words = sentence.split()

result = ''

for word in words:
  if result == "":
    result = word
  else:
    result = result + " " + word

print("Updated Sentence:",result)
# Out:
# Enter a sentence:Python    is     very   easy
# Updated Sentence: Python is very easy

# %%
#Count Occurrences of a Substring

string = input("Enter a string:")
substring = input("Enter a substring:")

count = 0

for i in range(len(string) - len(substring) + 1):
  part = string[i:i+len(substring)]

  if part == substring:
    count += 1

print("Occurences:",count)
# Out:
# Enter a string:abababa
# Enter a substring:aba
# Occurences: 3
