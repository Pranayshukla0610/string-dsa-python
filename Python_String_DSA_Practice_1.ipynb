# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/string-dsa-python/blob/main/Python_String_DSA_Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Reverse a String ⭐
#Problem

#Given a string, print its reverse.

#Input
#Python
#Output
#Reversed String: nohtyP

str = input("Enter a string:")

print("Reversed String:",str[::-1])
# Out:
# Enter a string:Python
# Reversed String: nohtyP

# %%
str = input("Enter a string:")
reversed_string = ""

for char in range(len(str)-1,-1,-1):
  reversed_string += str[char]

print("Reversed String:",reversed_string)
# Out:
# Enter a string:Programming
# Reversed String: gnimmargorP

# %%
#Check Whether a String is Palindrome

string = input("Enter a string:")

if string == string[::-1]:
  print("String is Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a string:madam
# String is Palindrome

# %%
string = input("Enter a string:")

reversed_string = ""

for char in range(len(string)-1,-1,-1):
  reversed_string += string[char]

if string == reversed_string:
  print("String is Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a string:listen
# Not Palindrome

# %%
#Count Vowels and Consonants ⭐
#Problem

#Count the number of vowels and consonants.

#Input
#Programming
#Output
#Vowels = 3
#Consonants = 8

string = input("Enter a string:")
vowels = 0
consonants = 0

for char in string:
  if char.lower() in "aeiou":
    vowels += 1
  elif char.isalpha():
    consonants += 1

print("Vowels Count:",vowels)
print("Consonants Count:",consonants)
# Out:
# Enter a string:Programming
# Vowels Count: 3
# Consonants Count: 8

# %%
#Count Frequency of Each Character

string = input("Enter a string:")

freq = {}

for char in string:
  if char in freq:
    freq[char] += 1
  else:
    freq[char] = 1

print("Frequency Count:",freq)
# Out:
# Enter a string:Programming
# Frequency Count: {'P': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
#Remove Duplicate Characters

string = input("Enter a string:")

result = ""

for char in string:
  if char not in result:
    result += char

print("After Removing Duplicates:",result)
# Out:
# Enter a string:Programming
# After Removing Duplicates: Progamin

# %%
#Check Whether Two Strings are Anagrams
#Input
#listen
#silent
#Output
#Anagram

string1 = input("Enter 1st string:")
string2 = input("Enter 2nd string:")

if sorted(string1) == sorted(string2):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# Enter 1st string:silent
# Enter 2nd string:listen
# Anagram

# %%
#Find the First Non-Repeating Character
#Input
#swiss
#Output
#First Non-Repeating Character: w

string = input("Enter a string:")

freq = {}

for ch in string:
  freq[ch] = freq.get(ch,0) + 1

found = False

for ch in string:
  if freq[ch] == 1:
    print("First Non-Repeating Character:",ch)
    found = True
    break

if not found:
  print("No Non-Repeating Character")
# Out:
# Enter a string:swiss
# First Non-Repeating Character: w

# %%
#Find the Most Frequent Character

string = input("Enter a string:")

max_count = 0
freq = {}
max_char = ''

for ch in string:
  freq[ch] = freq.get(ch, 0) + 1

for ch in string:
  if freq[ch] > max_count:
    max_count = freq[ch]
    max_char = ch

print("Most Frequent Character:",max_char)
print("Frequency:",max_count)
# Out:
# Enter a string:success
# Most Frequent Character: s
# Frequency: 3

# %%
#Count Words in a Sentence

sentence = input("Enter a sentence: ")

words = sentence.split()

count = 0

for word in words:
    count += 1

print("Total Words =", count)
# Out:
# Enter a sentence: Python is easy to learn
# Total Words = 5

# %%
#Find the Longest Word in a Sentence

sentence = input("Enter a sentence:")

words = sentence.split()

longest_word = ''

for word in words:
  if len(word) > len(longest_word):
    longest_word = word

print("Longest Word:",longest_word)
# Out:
# Enter a sentence:Find the Longest Word in a Sentence
# Longest Word: Sentence
